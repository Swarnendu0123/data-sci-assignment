# %% [markdown]
# ```
# Q1. How do you comment code in Python? What are the different types of comments?
# ```

# %%
# this is a comments

# %% [markdown]
# ```
# Q2. What are variables in Python? How do you declare and assign values to variables?
# ```

# %%
# Defination : variables are like containers, which can some value or information
institute = "IIT Kharagpur" # declearing and assigning value to the variable institute

# %% [markdown]
# ```
# Q3. How do you convert one data type to another in Python?
# ```

# %%
# we can convert the datatype by various methods
# converting the data type by simpally re assigning the value
a = 1
print(type(a))
a = 1.2
print(type(a))

# converting the variable by using function of that particular datatype
my_gpa = [8.08, 8.17, 8.7, 9.04]
print(type(my_gpa))
my_gpa = tuple(my_gpa)
print(type(my_gpa))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'tuple'>

# %% [markdown]
# ```
# Q4. How do you write and execute a Python script from the command line?
# ```

# %% [markdown]
# we can run a python file named test.py by writing
# ```
# python test.py
# ```
# on terminal

# %% [markdown]
# ```
# Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].
# ```

# %%
my_list = [1, 2, 3, 4, 5]
my_list.pop()
my_list.pop()
my_list.pop(0)
my_list
# Out:
# [2, 3]

# %% [markdown]
# ```
# Q6. What is a complex number in mathematics, and how is it represented in Python?
# ```

# %% [markdown]
# complex number is a number which have both real and imaginary part.
# eg: r = x+iy, here the x is the real part of r and the y is the imaginary part of r

# %%
# in python we can represent the complex number liske this
c = 2 + 4j
type(c)
# Out:
# complex

# %% [markdown]
# ```
# Q7. What is the correct way to declare a variable named age and assign the value 25 to it?
# ```

# %%
age = 25

# %% [markdown]
# ```
# Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable
# belong to?
# ```

# %%
price = 9.99 # float
type(price)
# Out:
# float

# %% [markdown]
# ```
# Q9. Create a variable named name and assign your full name to it as a string. How would you print the
# value of this variable?
# ```

# %%
name = "Swarnendu Bhandari"
print(name) # printing the value of the variable
# Out:
# Swarnendu Bhandari

# %% [markdown]
# ```
# Q10. Given the string "Hello, World!", extract the substring "World".
# ```

# %%
geetings = "Hello, World!"
substring = geetings[7:12]
substring
# Out:
# 'World'

# %% [markdown]
# ```
# Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are
# currently a student or not.
# ```

# %%
is_student = True
