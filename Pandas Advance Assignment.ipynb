# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd

# %%
#opens csv files
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# claculating mean
df["housing_median_age"].mean()
# Out:
# 28.845333333333333

# %%
# claculating standard deviation
df["housing_median_age"].std()
# Out:
# 12.555395554955753

# %%
# describe function
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
# plotes a dataframe
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
A = [1,2,3,4,5,6,7,8,9]
B = [2,4,6,8,10,12,14,16,18]
C = [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
def re_index(df):
  new_index = pd.Index(range(1, len(df)*2 + 1, 2))
  df = df.set_index(new_index)
  return df

# %%
df1 = pd.DataFrame({"A": A, "B":B, "C":C})

# %%
df1
# Out:
#    A   B   C
# 0  1   2   1
# 1  2   4   4
# 2  3   6   9
# 3  4   8  16
# 4  5  10  25
# 5  6  12  36
# 6  7  14  49
# 7  8  16  64
# 8  9  18  81

# %%
df1 = re_index(df1)

# %%
df1
# Out:
#     A   B   C
# 1   1   2   1
# 3   2   4   4
# 5   3   6   9
# 7   4   8  16
# 9   5  10  25
# 11  6  12  36
# 13  7  14  49
# 15  8  16  64
# 17  9  18  81

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console.

# %%
def print_sum(df, col):
  li = list(df[col][0:3])
  sum = 0
  for ele in li:
    sum = sum + ele
  print(sum)

# %%
df1["Values"] = [10, 20, 30, 40, 50, 0, 0, 0, 0]
df1
# Out:
#     A   B   C  Values
# 1   1   2   1      10
# 3   2   4   4      20
# 5   3   6   9      30
# 7   4   8  16      40
# 9   5  10  25      50
# 11  6  12  36       0
# 13  7  14  49       0
# 15  8  16  64       0
# 17  9  18  81       0

# %%
print_sum(df1, "Values")
# Out:
# 60

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
Text = ["The food was delicious and the service was excellent.",
"The hotel was clean and the staff was friendly.",
 "I loved the atmosphere and the drinks were great.",
"The movie was entertaining and the acting was superb.",
"The book was thought-provoking and well-written.",
"The concert was amazing and the music was fantastic.",
"The play was hilarious and the cast was talented.",
"The museum was informative and the exhibits were fascinating.",
"The game was exciting and the graphics were impressive."]

# %%
df1['Text']= Text

# %%
df1
# Out:
#     A   B   C  Values                                               Text
# 1   1   2   1      10  The food was delicious and the service was exc...
# 3   2   4   4      20    The hotel was clean and the staff was friendly.
# 5   3   6   9      30  I loved the atmosphere and the drinks were great.
# 7   4   8  16      40  The movie was entertaining and the acting was ...
# 9   5  10  25      50   The book was thought-provoking and well-written.
# 11  6  12  36       0  The concert was amazing and the music was fant...
# 13  7  14  49       0  The play was hilarious and the cast was talented.
# 15  8  16  64       0  The museum was informative and the exhibits we...
# 17  9  18  81       0  The game was exciting and the graphics were im...

# %%
new_index = pd.Index(range(0, 9, 1))
df1 = df1.set_index(new_index)

# %%
df1
# Out:
#    A   B   C  Values                                               Text
# 0  1   2   1      10  The food was delicious and the service was exc...
# 1  2   4   4      20    The hotel was clean and the staff was friendly.
# 2  3   6   9      30  I loved the atmosphere and the drinks were great.
# 3  4   8  16      40  The movie was entertaining and the acting was ...
# 4  5  10  25      50   The book was thought-provoking and well-written.
# 5  6  12  36       0  The concert was amazing and the music was fant...
# 6  7  14  49       0  The play was hilarious and the cast was talented.
# 7  8  16  64       0  The museum was informative and the exhibits we...
# 8  9  18  81       0  The game was exciting and the graphics were im...

# %%
Word_Count = []
for i in range(len(df1["Text"])):
  Word_Count.append(len(df1["Text"][i].split(" ")))

# %%
df1["Word_Count"]= Word_Count

# %%
df1
# Out:
#    A   B   C  Values                                               Text  \
# 0  1   2   1      10  The food was delicious and the service was exc...
# 1  2   4   4      20    The hotel was clean and the staff was friendly.
# 2  3   6   9      30  I loved the atmosphere and the drinks were great.
# 3  4   8  16      40  The movie was entertaining and the acting was ...
# 4  5  10  25      50   The book was thought-provoking and well-written.
# 5  6  12  36       0  The concert was amazing and the music was fant...
# 6  7  14  49       0  The play was hilarious and the cast was talented.
# 7  8  16  64       0  The museum was informative and the exhibits we...
# 8  9  18  81       0  The game was exciting and the graphics were im...
#
#    Word_Count
# 0           9
# 1           9
# 2           9
# 3           9
# 4           6
# 5           9
# 6           9
# 7           9
# 8           9

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %%
print(df.size)
print(df.shape)
# Out:
# 27000
# (3000, 9)

# %%
# df.size : gives number of cell ie, row* column of a data frame
# df.shape : gives the row and column of a data frame

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %%
# .read_excel() function is uded to read a excel file in pandas

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
df2 = pd.DataFrame({"e_mail" : [
  "johndoe@gmail.com",
  "sarahsmith@gmail.com",
  "robertjones@gmail.com",
  "emilywilson@gmail.com",
  "chrisbrown@gmail.com",
  "lindajackson@gmail.com",
  "markthompson@gmail.com",
  "lisasmith@gmail.com",
  "kevinmiller@gmail.com",
  "amandajohnson@gmail.com"
]}
)

# %%
def extract_username(df2):
  usernames = []
  for i in range(len(df2["e_mail"])):
    usernames.append(df2["e_mail"][i].split("@")[0])
  return usernames

# %%
username = extract_username(df2)
df2["user_name"] = username
df2
# Out:
#                     e_mail      user_name
# 0        johndoe@gmail.com        johndoe
# 1     sarahsmith@gmail.com     sarahsmith
# 2    robertjones@gmail.com    robertjones
# 3    emilywilson@gmail.com    emilywilson
# 4     chrisbrown@gmail.com     chrisbrown
# 5   lindajackson@gmail.com   lindajackson
# 6   markthompson@gmail.com   markthompson
# 7      lisasmith@gmail.com      lisasmith
# 8    kevinmiller@gmail.com    kevinmiller
# 9  amandajohnson@gmail.com  amandajohnson

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
# For example, if df contains the following values:
# ```
#   A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
# ```

# %%
A = [3,8,6,2,9]
B = [5,2,9,3,1]
C = [1,7,4,5,2]

# %%
df3 = pd.DataFrame({"A":A,"B":B, "C":C})

# %%
df3
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def get_df(df):
  return df[(df["A"] > 5) & (df["B"] < 10)]

# %%
get_df(df3)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
import numpy as np

# %%
def calculate(df):
  print("mean: ",np.mean(df["Values"]))
  print("median: ",np.median(df["Values"]))
  print("Standard deviation: ",np.std(df["Values"]))

# %%
df1
# Out:
#    A   B   C  Values                                               Text  \
# 0  1   2   1      10  The food was delicious and the service was exc...
# 1  2   4   4      20    The hotel was clean and the staff was friendly.
# 2  3   6   9      30  I loved the atmosphere and the drinks were great.
# 3  4   8  16      40  The movie was entertaining and the acting was ...
# 4  5  10  25      50   The book was thought-provoking and well-written.
# 5  6  12  36       0  The concert was amazing and the music was fant...
# 6  7  14  49       0  The play was hilarious and the cast was talented.
# 7  8  16  64       0  The museum was informative and the exhibits we...
# 8  9  18  81       0  The game was exciting and the graphics were im...
#
#    Word_Count
# 0           9
# 1           9
# 2           9
# 3           9
# 4           6
# 5           9
# 6           9
# 7           9
# 8           9

# %%
calculate(df1)
# Out:
# mean:  16.666666666666668
# median:  10.0
# Standard deviation:  18.257418583505537

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
import random
from datetime import datetime, timedelta

# Generate 100 random sales values (for demonstration, you can replace this with your actual data)
sales_data = [random.randint(100, 1000) for _ in range(100)]

# Generate a list of dates for 100 days starting from today
start_date = datetime.now()
date_list = [start_date + timedelta(days=i) for i in range(100)]

# Create a Pandas DataFrame
data = {'Date': date_list, 'Sales': sales_data}
df4 = pd.DataFrame(data)

# %%
df4
# Out:
#                          Date  Sales
# 0  2023-10-20 02:59:19.695476    410
# 1  2023-10-21 02:59:19.695476    196
# 2  2023-10-22 02:59:19.695476    575
# 3  2023-10-23 02:59:19.695476    856
# 4  2023-10-24 02:59:19.695476    957
# ..                        ...    ...
# 95 2024-01-23 02:59:19.695476    975
# 96 2024-01-24 02:59:19.695476    258
# 97 2024-01-25 02:59:19.695476    974
# 98 2024-01-26 02:59:19.695476    441
# 99 2024-01-27 02:59:19.695476    463
#
# [100 rows x 2 columns]

# %%
MovingAverage = []
for i in range(6, 100):
  MovingAverage.append(np.mean(df4['Sales'][i-6:i+1]))

# %%
MovingAverage = [0,0,0,0,0,0]+MovingAverage

# %%
len(MovingAverage)
# Out:
# 100

# %%
df4["MovingAverage"]= MovingAverage

# %%
df4
# Out:
#                          Date  Sales  MovingAverage
# 0  2023-10-20 02:59:19.695476    410       0.000000
# 1  2023-10-21 02:59:19.695476    196       0.000000
# 2  2023-10-22 02:59:19.695476    575       0.000000
# 3  2023-10-23 02:59:19.695476    856       0.000000
# 4  2023-10-24 02:59:19.695476    957       0.000000
# ..                        ...    ...            ...
# 95 2024-01-23 02:59:19.695476    975     512.000000
# 96 2024-01-24 02:59:19.695476    258     496.571429
# 97 2024-01-25 02:59:19.695476    974     506.000000
# 98 2024-01-26 02:59:19.695476    441     525.142857
# 99 2024-01-27 02:59:19.695476    463     575.285714
#
# [100 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# ```
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# ```
# Your function should create the following DataFrame:
# ```
#         Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# ```
# The function should return the modified DataFrame.

# %%
dates = ["2023-01-01","2023-01-02","2023-01-03","2023-01-04","2023-01-05"]
df5 = pd.DataFrame({"Date":dates})

# %%
df5
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
from datetime import datetime
def add_week_day(df5):
  Weekday = []
  for i in range(len(df5)):
    year = int(df5["Date"][i].split("-")[0])
    month = int(df5["Date"][i].split("-")[1])
    day = int(df5["Date"][i].split("-")[2])
    # Createing a datetime object
    x = datetime(year, month, day)
    days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
    # Geting the name of the weekday
    weekday_name = days[x.weekday()]
    Weekday.append(weekday_name)

  df5["Weekday"]= Weekday

# %%
add_week_day(df5)
df5
# Out:
#          Date    Weekday
# 0  2023-01-01     Sunday
# 1  2023-01-02     Monday
# 2  2023-01-03    Tuesday
# 3  2023-01-04  Wednesday
# 4  2023-01-05   Thursday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
# Sample DataFrame with 'Date' column containing timestamps
data = {'Date': ['2023-01-15', '2023-02-10', '2023-01-05', '2023-02-20']}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])  # Convert the 'Date' column to datetime format

# %%
df
# Out:
#         Date
# 0 2023-01-15
# 1 2023-02-10
# 2 2023-01-05
# 3 2023-02-20

# %%
def select_rows_in_date_range(dataframe, start_date, end_date):
    mask = (dataframe['Date'] >= start_date) & (dataframe['Date'] <= end_date)
    selected_rows = dataframe[mask]
    return selected_rows

# %%
# Define the start and end date for your range
start_date = pd.to_datetime('2023-01-01')
end_date = pd.to_datetime('2023-01-31')

# %%
# Use the function to select rows within the specified date range
selected_rows = select_rows_in_date_range(df, start_date, end_date)

# Print the selected rows
print(selected_rows)
# Out:
#         Date
# 0 2023-01-15
# 2 2023-01-05

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %% [markdown]
# to use basic functions of pandas we need to import pandas
# ```
# import pandas as pd
#
# ```

# %%
df4
# Out:
#                          Date  Sales  MovingAverage
# 0  2023-10-20 02:59:19.695476    410       0.000000
# 1  2023-10-21 02:59:19.695476    196       0.000000
# 2  2023-10-22 02:59:19.695476    575       0.000000
# 3  2023-10-23 02:59:19.695476    856       0.000000
# 4  2023-10-24 02:59:19.695476    957       0.000000
# ..                        ...    ...            ...
# 95 2024-01-23 02:59:19.695476    975     512.000000
# 96 2024-01-24 02:59:19.695476    258     496.571429
# 97 2024-01-25 02:59:19.695476    974     506.000000
# 98 2024-01-26 02:59:19.695476    441     525.142857
# 99 2024-01-27 02:59:19.695476    463     575.285714
#
# [100 rows x 3 columns]
