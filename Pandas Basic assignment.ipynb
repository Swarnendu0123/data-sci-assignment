# %%
import pandas as pd

# %% [markdown]
# ```
# Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.
# ```

# %%
nums = pd.Series([4, 8, 15, 16, 23, 42])

# %%
nums
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %% [markdown]
# ```
# Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the
# variable print it.
# ```

# %%
import random as r

# %%
my_list = []
for i in range(10):
  my_list.append((int(r.random()*10)))

# %%
my_list
# Out:
# [6, 7, 5, 4, 6, 7, 3, 2, 3, 7]

# %%
pd.Series(my_list)
# Out:
# 0    6
# 1    7
# 2    5
# 3    4
# 4    6
# 5    7
# 6    3
# 7    2
# 8    3
# 9    7
# dtype: int64

# %% [markdown]
# ```
# Q3. Create a Pandas DataFrame that contains the following data:
# Name          Age     Gender
# Alice         25      Female
# Bob           30      Male
# Claire        27      Female
# ```

# %%
name = ["Alice","Bob","Claire"]
age = [25,30,27]
gender = ["female","male","female"]

# %%
df1 = pd.DataFrame({"name": name, "age":age,"gender":gender})

# %%
df1
# Out:
#      name  age  gender
# 0   Alice   25  female
# 1     Bob   30    male
# 2  Claire   27  female
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df1, *['age'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %% [markdown]
# ```
# Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.
# ```

# %%
# Dataframe : data freame is a table of parsed data in pandas
# Series : it is the each column data of a DataFrame, thus it is different from pandas
# DataFrame:
print("Data Frame")
print(df1)
# Series:
print("\n\nName Series")
print(df1["name"])
# Out:
# Data Frame
#      name  age  gender
# 0   Alice   25  female
# 1     Bob   30    male
# 2  Claire   27  female
#
#
# Name Series
# 0     Alice
# 1       Bob
# 2    Claire
# Name: name, dtype: object

# %% [markdown]
# ```
# Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can
# you give an example of when you might use one of these functions?
# ```

# %%
# read_csv(path): to read DataFrame from a csv file
# read_html(url): to read a DataFrame from any Website
# read_excel(path): to read DataFrame form any excel file
# .head(n) : to get first n rows from Data Frame
# .tail(n) : to get last n rows from Data Frame
# .columns : to get the all Series heading from a Data frame (but its an property not a function)
# .dtypes : to get the datatype of all Series (but its an property not a function)

# %% [markdown]
# ```
# Q6. Which of the following is mutable in nature Series, DataFrame, Panel?
# ```

# %%
# Series

# %% [markdown]
# ```
# Q7. Create a DataFrame using multiple Series. Explain with an example.
# ```

# %%
import pandas as pd

# Create pandas Series
courses = pd.Series(["Spark", "PySpark", "Hadoop"])
fees = pd.Series([22000, 25000, 23000])
discount = pd.Series([1000, 2300, 1000])

# Combine multiple series into a DataFrame
df = pd.DataFrame({"courses":courses, "fees":fees, "discount":discount})
df
# Out:
#    courses   fees  discount
# 0    Spark  22000      1000
# 1  PySpark  25000      2300
# 2   Hadoop  23000      1000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['fees'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
# ...
